# %% [markdown]
# # Demo of Utilizing New GraphQL API for SNP Data

# %% [markdown]
# ## Setting Up API Connection
#
# The script begins by setting up a connection to a GraphQL API, specifying the base URL and the endpoint.

# %%
import requests
import json
import pandas as pd
from config.settings import settings

BASE_URL = settings.API_URL
GRAPHQL_ENDPOINT = 'graphql'

# %% [markdown]
# ## Understanding Annotations in the API
#
# It executes a GET request to retrieve a list of annotations. These annotations describe various data fields available through the API, detailing their characteristics such as name, description, and how they relate to each other in a hierarchical manner, much like a structured catalog of options you can query.
#
# **api_field:** Specifies the field name as it should be used in API requests, particularly when crafting queries for a GraphQL API. This ensures you're asking for data in a format the API understands.

# %%
response = requests.get(f"{BASE_URL}annotations")

annotations = response.json()
annotations
# Out:
# {'results': [{'id': '0',
#    'leaf': False,
#    'name': 'root',
#    'label': 'Annotation',
#    'sort': 0.0},
#   {'id': '1',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'Basic Info',
#    'detail': 'Basic information about the variant, such as chromosome number, position, etc.',
#    'sort': 1.0},
#   {'id': '26',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'ANNOVAR',
#    'detail': 'Pre-computed ANNOVAR annotations for all alternative SNVs based on human reference genome hg19',
#    'link': 'http://annovar.openbioinformatics.org/en/latest/user-guide/download/',
#    'pmid': '20601685',
#    'sort': 2.0},
#   {'id': '208',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'SnpEff',
#    'detail': 'AnpEff is a program for annotating and predicting the effects of single nucleotide polymorphisms',
#    'link': 'http://pcingola.github.io/SnpEff/',
#    'pmid': '22728672',
#    'sort': 3.0},
#   {'id': '132',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'VEP',
#    'detail': 'Variant Effect Predictor (VEP) is developed by Ensembl and it determines the effect of the variants (SNPs, insertions, deletions, CNVs or structural variants) on genes, transcripts, and protein sequence, as well as regulatory regions. ',
#    'link': 'https://uswest.ensembl.org/info/docs/tools/vep/index.html',
#    'pmid': '27268795',
#    'sort': 4.0},
#   {'id': '83',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'AnnoQ Functional Annotations',
#    'label': 'PANTHER Functional Annotation',
#    'detail': 'Functional annotation of a variant through PANTHER API.',
#    'link': 'http://pantherdb.org',
#    'pmid': '33290554',
#    'sort': 5.0},
#   {'id': '7',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'IMAGE Enhancer Linked Functional Annotations',
#    'label': 'PEREGRINE Functional Annotations',
#    'detail': 'When the variant is located in an enhancer region, the functions of its target gene inferred from the enhancer-gene links in the PEREGRINE project The ontology terms are annotated here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'sort': 6.0},
#   {'id': '288', 'parent_id': '0', 'leaf': False, 'name': 'allele frequencies'},
#   {'id': '469',
#    'parent_id': '0',
#    'leaf': False,
#    'name': 'disease related databases'},
#   {'id': '495', 'parent_id': '0', 'leaf': False, 'name': 'others'},
#   {'id': '2',
#    'parent_id': '1',
#    'leaf': True,
#    'name': 'chr',
#    'detail': 'Chromosome number of the variant.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'chr'},
#   {'id': '3',
#    'parent_id': '1',
#    'leaf': True,
#    'name': 'pos',
#    'detail': 'Position of the variant.',
#    'field_type': 'long',
#    'api_field': 'pos'},
#   {'id': '4',
#    'parent_id': '1',
#    'leaf': True,
#    'name': 'ref',
#    'detail': 'The reference base of the variant.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ref'},
#   {'id': '5',
#    'parent_id': '1',
#    'leaf': True,
#    'name': 'alt',
#    'detail': 'The alternative allele of the variant.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'alt'},
#   {'id': '6',
#    'parent_id': '1',
#    'leaf': True,
#    'name': 'rs_dbSNP151',
#    'label': 'rs ID',
#    'detail': 'dbSNP ID if available. The current release supports rs IDs from dbSNP build 151.',
#    'root_url': 'https://www.ncbi.nlm.nih.gov/snp/',
#    'sample_url': 'https://www.ncbi.nlm.nih.gov/snp/rs6883035',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'rs_dbSNP151'},
#   {'id': '9',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_GO_biological_process_complete_list_id',
#    'label': 'PEREGRINE_enhancer_linked_GO_biological_process_complete_list_id',
#    'detail': 'When the variant is located in an enhancer region, the complete GO biological process annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_GO_biological_process_complete_list_id'},
#   {'id': '11',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_GO_cellular_component_complete_list_id',
#    'label': 'PEREGRINE_enhancer_linked_GO_cellular_component_complete_list_id',
#    'detail': 'When the variant is located in an enhancer region, the complete GO cellular component annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_GO_cellular_component_complete_list_id'},
#   {'id': '13',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_GO_molecular_function_complete_list_id',
#    'label': 'PEREGRINE_enhancer_linked_GO_molecular_function_complete_list_id',
#    'detail': 'When the variant is located in an enhancer region, the complete GO molecular function annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_GO_molecular_function_complete_list_id'},
#   {'id': '15',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id',
#    'label': 'PEREGRINE_enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'When the variant is located in an enhancer region, the GO slim biological process annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '17',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_PANTHER_GO_SLIM_cellular_component_list_id',
#    'label': 'PEREGRINE_enhancer_linked_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'When the variant is located in an enhancer region, the GO slim GO cellular component annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '19',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_PANTHER_GO_SLIM_molecular_function_list_id',
#    'label': 'PEREGRINE_enhancer_linked_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'When the variant is located in an enhancer region, the GO slim molecular function annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the GO IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '22',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_REACTOME_pathway_list_id',
#    'label': 'PEREGRINE_enhancer_linked_REACTOME_pathway_list_id',
#    'detail': 'When the variant is located in an enhancer region, the REACTOME pathway annotations of its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here. Only the REACTOME pathway IDs are displayed here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'enhancer_linked_REACTOME_pathway_list_id'},
#   {'id': '23',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_assay',
#    'label': 'PEREGRINE_enhancer_linked_assay',
#    'detail': "When the variant is located in an enhancer region, the assay data used to infer its link to the target genes by the PEREGRINE project are listed here. For example, single tissue eQTL, interactive TAD, ChIA-PET. These assays are usually tissue-specific. The tissue data is in the 'PEREGRINE_enhancer_linked_tissue' annotation.",
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'api_field': 'enhancer_linked_assay'},
#   {'id': '24',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_genes',
#    'label': 'PEREGRINE_enhancer_linked_genes',
#    'detail': 'When the variant is located in an enhancer region, its target genes inferred from the enhancer-gene links in the PEREGRINE project are populated here.',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'enhancer_linked_genes'},
#   {'id': '25',
#    'parent_id': '7',
#    'leaf': True,
#    'name': 'enhancer_linked_enhancer',
#    'label': 'PEREGRINE_mapped_enhancer',
#    'detail': 'The PEREGRINE enhancer ID of an enhancer region where the variant is located',
#    'link': 'https://www.peregrineproj.org/',
#    'pmid': '33320871',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'enhancer_linked_enhancer'},
#   {'id': '27',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_Closest_gene(intergenic_only)',
#    'detail': 'cloest genes if the variant is intergenic.\\nFormat gene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)\\ngene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)',
#    'root_url': 'http://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=',
#    'sample_url': 'http://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000158270',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_Closest_gene'},
#   {'id': '28',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_Effect',
#    'detail': 'ANNOVAR consequence with Ensembl as gene model.\\nMultiple consequences are separated by "|" The order corresponds to ANNOVAR_ensembl_Transcript_ID\\nThe order corresponds to ANNOVAR_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_Effect'},
#   {'id': '29',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_Exon_Rank',
#    'detail': 'exon number the variant locates (if applicable)\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_ensembl_Transcript_ID\\nThe order corresponds to ANNOVAR_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_Exon_Rank'},
#   {'id': '31',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_GO_biological_process_complete_list_id'},
#   {'id': '33',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_GO_cellular_component_complete_list_id'},
#   {'id': '35',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_GO_molecular_function_complete_list_id'},
#   {'id': '36',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_Gene_ID',
#    'detail': 'Ensembl gene IDs corresponding to transcripts. Multiple IDs are separated by "|". The order corresponds to ANNOVAR_ensembl_Transcript_ID. The gene IDs can be the same for different transcript IDs.',
#    'root_url': 'http://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=',
#    'sample_url': 'http://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000158270',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_Gene_ID'},
#   {'id': '37',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_HGVSc',
#    'detail': 'variant in format of HGVSc. Multiple annotations are separated by "|". The order corresponds to ANNOVAR_ensembl_Transcript_ID.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_HGVSc'},
#   {'id': '38',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_HGVSp',
#    'detail': 'variant in format of HGVSp. Multiple annotations are separated by "|". The order corresponds to ANNOVAR_ensembl_Transcript_ID.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_HGVSp'},
#   {'id': '40',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'The PANTHER GO Slim biological process ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '42',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'The PANTHER GO Slim cellular component ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '44',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'The PANTHER GO Slim molecular function ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '46',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_PANTHER_pathway_list_id',
#    'detail': 'The PANTHER pathway ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of PANTHER Pathway IDs from all genes are shown here. The order of the IDs corresponds to that of the terms in the term column.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_PANTHER_pathway_list_id'},
#   {'id': '48',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_REACTOME_pathway_list_id',
#    'detail': 'The REACTOME Pathway ID list queried through PANTHER API for IDs corresponding to ANNOVAR_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of REACTOME Pathway IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_ensembl_REACTOME_pathway_list_id'},
#   {'id': '49',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_Transcript_ID',
#    'detail': 'Ensembl transcript IDs corresponding to consequences.\\nMultiple IDs are separated by "|"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_Transcript_ID'},
#   {'id': '50',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ensembl_summary',
#    'detail': 'ANNOVAR consequence summary with Ensembl as gene model.\\nFormat GeneID(total number of transcripts):consequence#1(number of transcripts affected) consequence#2(number of transcripts affected)... Multiple genes are separated by "|"\\nGeneID(total number of transcripts):consequence#1(number of transcripts affected)\\nconsequence#2(number of transcripts affected)... Multiple genes are separated by "|"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ensembl_summary'},
#   {'id': '51',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_Closest_gene(intergenic_only)',
#    'detail': 'cloest genes if the variant is intergenic.\\nFormat gene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)\\ngene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_Closest_gene'},
#   {'id': '52',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_Effect',
#    'detail': 'ANNOVAR consequence with RefSeq as gene model.\\nMultiple consequences are separated by "|" The order corresponds to ANNOVAR_refseq_Transcript_ID\\nThe order corresponds to ANNOVAR_refseq_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_Effect'},
#   {'id': '53',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_Exon_Rank',
#    'detail': 'exon number the variant locates (if applicable)\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_refseq_Transcript_ID\\nThe order corresponds to ANNOVAR_refseq_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_Exon_Rank'},
#   {'id': '55',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_GO_biological_process_complete_list_id'},
#   {'id': '57',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_GO_cellular_component_complete_list_id'},
#   {'id': '59',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_GO_molecular_function_complete_list_id'},
#   {'id': '60',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_Gene_ID',
#    'detail': 'RefSeq gene IDs corresponding to transcripts.\\nMultiple IDs are separated by "|" The order corresponds to ANNOVAR_refseq_Transcript_ID\\nThe order corresponds to ANNOVAR_refseq_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_Gene_ID'},
#   {'id': '61',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_HGVSc',
#    'detail': 'variant in format of HGVSc.\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_refseq_Transcript_ID\\nThe order corresponds to ANNOVAR_refseq_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_HGVSc'},
#   {'id': '62',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_HGVSp',
#    'detail': 'variant in format of HGVSp.\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_refseq_Transcript_ID\\nThe order corresponds to ANNOVAR_refseq_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_HGVSp'},
#   {'id': '64',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'The PANTHER GO Slim biological process ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '66',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'The PANTHER GO Slim cellular component ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '68',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'The PANTHER GO Slim molecular function ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '70',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_PANTHER_pathway_list_id',
#    'detail': 'The PANTHER pathway ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of PANTHER Pathway IDs from all genes are shown here. The order of the IDs corresponds to that of the terms in the term column.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_PANTHER_pathway_list_id'},
#   {'id': '72',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_REACTOME_pathway_list_id',
#    'detail': 'The REACTOME Pathway ID list queried through PANTHER API for IDs corresponding to ANNOVAR_refseq_Transcript_ID column. If there are more than one gene ID, a non-redundant list of REACTOME Pathway IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'ANNOVAR_refseq_REACTOME_pathway_list_id'},
#   {'id': '73',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_Transcript_ID',
#    'detail': 'RefSeq transcript IDs corresponding to consequences.\\nMultiple IDs are separated by "|"',
#    'root_url': 'https://www.ncbi.nlm.nih.gov/nuccore/',
#    'sample_url': 'https://www.ncbi.nlm.nih.gov/nuccore/NM_130386',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_Transcript_ID'},
#   {'id': '74',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_refseq_summary',
#    'detail': 'ANNOVAR consequence summary with RefSeq as gene model.\\nFormat GeneID(total number of transcripts):consequence#1(number of transcripts affected) consequence#2(number of transcripts affected)... Multiple genes are separated by "|"\\nGeneID(total number of transcripts):consequence#1(number of transcripts affected)\\nconsequence#2(number of transcripts affected)... Multiple genes are separated by "|"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_refseq_summary'},
#   {'id': '75',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_Closest_gene(intergenic_only)',
#    'detail': 'cloest genes if the variant is intergenic.\\nFormat gene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)\\ngene ID1:transcript ID1(dist=distance),gene ID2:transcript ID2(dist=distance)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_Closest_gene'},
#   {'id': '76',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_Effect',
#    'detail': 'ANNOVAR consequence with UCSC knownGene as gene model.\\nMultiple consequences are separated by "|" The order corresponds to ANNOVAR_ucsc_Transcript_ID\\nThe order corresponds to ANNOVAR_ucsc_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_Effect'},
#   {'id': '77',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_Exon_Rank',
#    'detail': 'exon number the variant locates (if applicable)\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_ucsc_Transcript_ID\\nThe order corresponds to ANNOVAR_ucsc_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_Exon_Rank'},
#   {'id': '78',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_Gene_ID',
#    'detail': 'UCSC gene IDs corresponding to transcripts.\\nMultiple IDs are separated by "|" The order corresponds to ANNOVAR_ucsc_Transcript_ID\\nThe order corresponds to ANNOVAR_ucsc_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_Gene_ID'},
#   {'id': '79',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_HGVSc',
#    'detail': 'variant in format of HGVSc.\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_ucsc_Transcript_ID\\nThe order corresponds to ANNOVAR_ucsc_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_HGVSc'},
#   {'id': '80',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_HGVSp',
#    'detail': 'variant in format of HGVSp.\\nMultiple annotations are separated by "|" The order corresponds to ANNOVAR_ucsc_Transcript_ID\\nThe order corresponds to ANNOVAR_ucsc_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_HGVSp'},
#   {'id': '81',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_Transcript_ID',
#    'detail': 'UCSC transcript IDs corresponding to consequences.\\nMultiple IDs are separated by "|"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_Transcript_ID'},
#   {'id': '82',
#    'parent_id': '26',
#    'leaf': True,
#    'name': 'ANNOVAR_ucsc_summary',
#    'detail': 'ANNOVAR consequence summary with UCSC as gene model.\\nFormat GeneID(total number of transcripts):consequence#1(number of transcripts affected) consequence#2(number of transcripts affected)... Multiple genes are separated by "|"\\nGeneID(total number of transcripts):consequence#1(number of transcripts affected)\\nconsequence#2(number of transcripts affected)... Multiple genes are separated by "|"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ANNOVAR_ucsc_summary'},
#   {'id': '85',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_GO_biological_process_complete_list_id'},
#   {'id': '87',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_GO_cellular_component_complete_list_id'},
#   {'id': '89',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_GO_molecular_function_complete_list_id'},
#   {'id': '91',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'The PANTHER GO slim biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '93',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'The  PANTHER GO slim cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '95',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'The PANTHER GO slim molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '97',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_PANTHER_pathway_list_id',
#    'detail': 'The PANTHER Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_PANTHER_pathway_list_id'},
#   {'id': '99',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_0_REACTOME_pathway_list_id',
#    'detail': 'The REACTOME Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region with 0 flanking region.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_0_REACTOME_pathway_list_id'},
#   {'id': '101',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_GO_biological_process_complete_list_id'},
#   {'id': '103',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_GO_cellular_component_complete_list_id'},
#   {'id': '105',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_GO_molecular_function_complete_list_id'},
#   {'id': '107',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'The PANTHER GO slim biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '109',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'The  PANTHER GO slim cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '111',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'The PANTHER GO slim molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '113',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_PANTHER_pathway_list_id',
#    'detail': 'The PANTHER Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_PANTHER_pathway_list_id'},
#   {'id': '115',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_10000_REACTOME_pathway_list_id',
#    'detail': 'The REACTOME Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_10000_REACTOME_pathway_list_id'},
#   {'id': '117',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_GO_biological_process_complete_list_id'},
#   {'id': '119',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_GO_cellular_component_complete_list_id'},
#   {'id': '121',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_GO_molecular_function_complete_list_id'},
#   {'id': '123',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_PANTHER_GO_SLIM_biological_process_list_id',
#    'detail': 'The PANTHER GO slim biological process ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_PANTHER_GO_SLIM_biological_process_list_id'},
#   {'id': '125',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_PANTHER_GO_SLIM_cellular_component_list_id',
#    'detail': 'The  PANTHER GO slim cellular component ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_PANTHER_GO_SLIM_cellular_component_list_id'},
#   {'id': '127',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_PANTHER_GO_SLIM_molecular_function_list_id',
#    'detail': 'The PANTHER GO slim molecular function ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_PANTHER_GO_SLIM_molecular_function_list_id'},
#   {'id': '129',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_PANTHER_pathway_list_id',
#    'detail': 'The PANTHER Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 20k flanking regions on either end.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_PANTHER_pathway_list_id'},
#   {'id': '131',
#    'parent_id': '83',
#    'leaf': True,
#    'name': 'flanking_20000_REACTOME_pathway_list_id',
#    'detail': 'The REACTOME Pathway ID list queried through PANTHER API for the gene(s) when the variant is within the gene region plus 10k flanking regions on either end.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'flanking_20000_REACTOME_pathway_list_id'},
#   {'id': '133',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_canonical',
#    'detail': 'canonical transcript predicted by Ensembl VEP.\\nMultiple entries separated by ";", matching Ensembl_transcriptid. See https://useast.ensembl.org/Help/Glossary?id=521\\nSee https://useast.ensembl.org/Help/Glossary?id=521',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_canonical'},
#   {'id': '134',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_Amino_Acid_Change',
#    'detail': 'amino acid change as to a transcript.\\nMultiple annotations are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID "*" represents a stop codon\\nThe order corresponds to VEP_ensembl_Transcript_ID\\n"*" represents a stop codon',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_Amino_Acid_Change'},
#   {'id': '135',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_CANONICAL',
#    'detail': 'whether a transcript is canonical.\\nMultiple annotations are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_CANONICAL'},
#   {'id': '136',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_CCDS',
#    'detail': 'CCDS IDs corresponding to transcripts.\\nMultiple IDs are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_CCDS'},
#   {'id': '137',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_CDS_position',
#    'detail': 'CDS position as to a transcript.\\nMultiple annotations are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_CDS_position'},
#   {'id': '138',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_Codon_Change_or_Distance',
#    'detail': 'codon change or distance as to a transcript.\\nMultiple annotations are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_Codon_Change_or_Distance'},
#   {'id': '139',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_Consequence',
#    'detail': 'VEP consequence with Ensembl as gene model.\\nMultiple consequences are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_Consequence'},
#   {'id': '140',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_Exon_or_Intron_Rank',
#    'detail': 'exon (intron) rank as to a transcript.\\nMultiple annotations are separated by "|" The order corresponds to VEP_ensembl_Transcript_ID\\nThe order corresponds to VEP_ensembl_Transcript_ID',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'VEP_ensembl_Exon_or_Intron_Rank'},
#   {'id': '142',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_GO_biological_process_complete_list_id',
#    'detail': 'The complete GO biological process ID list queried through PANTHER API for IDs corresponding to VEP_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'VEP_ensembl_GO_biological_process_complete_list_id'},
#   {'id': '144',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_GO_cellular_component_complete_list_id',
#    'detail': 'The complete GO cellular component ID list queried through PANTHER API for IDs corresponding to VEP_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'VEP_ensembl_GO_cellular_component_complete_list_id'},
#   {'id': '146',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_GO_molecular_function_complete_list_id',
#    'detail': 'The complete GO molecular function ID list queried through PANTHER API for IDs corresponding to VEP_ensembl_Gene_ID column. If there are more than one gene ID, a non-redundant list of GO IDs from all genes are shown here. The order of the GO IDs corresponds to that of the terms in the term column.',
#    'root_url': 'http://amigo.geneontology.org/amigo/term/',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'value_type': 'term_id',
#    'api_field': 'VEP_ensembl_GO_molecular_function_complete_list_id'},
#   {'id': '147',
#    'parent_id': '132',
#    'leaf': True,
#    'name': 'VEP_ensembl_Gene_ID',
# ...
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'PrimateAI_score'},
#   {'id': '580',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'RegulomeDB_motif',
#    'detail': 'motif the SNP resides (from RegulomeDB)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'RegulomeDB_motif'},
#   {'id': '581',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'RegulomeDB_score',
#    'detail': 'categorical score from RegulomeDB. The smaller, the more likely the SNP\\naffects binding',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'RegulomeDB_score'},
#   {'id': '582',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'Reliability_index',
#    'detail': 'Number of observed component scores (except the maximum frequency in\\nthe 1000 genomes populations) for MetaSVM and MetaLR. Ranges from 1 to 10. As MetaSVM and MetaLR scores are calculated based on imputed data, the less missing component scores, the higher the reliability of the scores and predictions.\\nand MetaLR scores are calculated based on imputed data, the less missing component\\nscores, the higher the reliability of the scores and predictions.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'Reliability_index'},
#   {'id': '583',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT4G_converted_rankscore',
#    'detail': 'SIFT4G scores were first converted to SIFT4Gnew=1-SIFT4G,\\nthen ranked among all SIFT4Gnew scores in dbNSFP. The rankscore is the ratio of the rank the SIFT4Gnew score over the total number of SIFT4Gnew scores in dbNSFP. If there are multiple scores, only the most damaging (largest) rankscore is presented.\\nthe rank the SIFT4Gnew score over the total number of SIFT4Gnew scores in dbNSFP.\\nIf there are multiple scores, only the most damaging (largest) rankscore is presented.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT4G_converted_rankscore'},
#   {'id': '584',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT4G_pred',
#    'detail': 'If SIFT4G is < 0.05 the corresponding nsSNV is\\npredicted as "D(amaging)"; otherwise it is predicted as "T(olerated)". Multiple scores separated by ",", corresponding to Ensembl_transcriptid\\nMultiple scores separated by ",", corresponding to Ensembl_transcriptid',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT4G_pred'},
#   {'id': '585',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT4G_score',
#    'detail': 'SIFT 4G score (SIFT4G). Scores range from 0 to 1. The smaller the score the\\nmore likely the SNP has damaging effect. Multiple scores separated by ",", corresponding to Ensembl_transcriptid\\nMultiple scores separated by ",", corresponding to Ensembl_transcriptid',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT4G_score'},
#   {'id': '586',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT_converted_rankscore',
#    'detail': 'SIFTori scores were first converted to SIFTnew=1-SIFTori,\\nthen ranked among all SIFTnew scores in dbNSFP. The rankscore is the ratio of the rank the SIFTnew score over the total number of SIFTnew scores in dbNSFP. If there are multiple scores, only the most damaging (largest) rankscore is presented. The rankscores range from 0.00964 to 0.91255.\\nthe rank the SIFTnew score over the total number of SIFTnew scores in dbNSFP.\\nIf there are multiple scores, only the most damaging (largest) rankscore is presented.\\nThe rankscores range from 0.00964 to 0.91255.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT_converted_rankscore'},
#   {'id': '587',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT_pred',
#    'detail': 'If SIFTori is smaller than 0.05 (rankscore>0.39575) the corresponding nsSNV is\\npredicted as "D(amaging)"; otherwise it is predicted as "T(olerated)". Multiple predictions separated by ";"\\nMultiple predictions separated by ";"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT_pred'},
#   {'id': '588',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'SIFT_score',
#    'detail': 'SIFT score (SIFTori). Scores range from 0 to 1. The smaller the score the\\nmore likely the SNP has damaging effect. Multiple scores separated by ";", corresponding to Ensembl_proteinid.\\nMultiple scores separated by ";", corresponding to Ensembl_proteinid.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'SIFT_score'},
#   {'id': '589',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'TSL',
#    'detail': 'Transcript Support Level.\\nMultiple entries separated by ";", matching Ensembl_transcriptid. Potential values 1 to 5, NA. See https://useast.ensembl.org/info/genome/genebuild/transcript_quality_tags.html\\nPotential values\\n1 to 5, NA.\\nSee https://useast.ensembl.org/info/genome/genebuild/transcript_quality_tags.html',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'TSL'},
#   {'id': '590',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'TWINSUK_AC',
#    'detail': 'Alternative allele count in called genotypes in UK10K TWINSUK cohort.',
#    'field_type': 'long',
#    'api_field': 'TWINSUK_AC'},
#   {'id': '591',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'TWINSUK_AF',
#    'detail': 'Alternative allele frequency in called genotypes in UK10K TWINSUK cohort.',
#    'field_type': 'float',
#    'api_field': 'TWINSUK_AF'},
#   {'id': '592',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'TWINSUK_AN',
#    'detail': 'Total allele count in called genotypes in UK10K TWINSUK cohort.',
#    'field_type': 'long',
#    'api_field': 'TWINSUK_AN'},
#   {'id': '593',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'TargetScan_context++_score_percentile',
#    'detail': 'context++ score is a measure of favorableness of the\\nsite for the miRNA family. The higer the percentile, the more favorable (from TargetScan)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'TargetScan_context_score_percentile'},
#   {'id': '594',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'UTR3_miRNA_target',
#    'detail': 'the gene-miRNA pair, if the site is located within a predicted (conserved)\\ntarget of conserved miRNA families(from TargetScan)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'UTR3_miRNA_target'},
#   {'id': '595',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'Uniprot_acc',
#    'detail': 'Uniprot accession number matching the Ensembl_proteinid\\nMultiple entries separated by ";".',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'Uniprot_acc'},
#   {'id': '596',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'Uniprot_entry',
#    'detail': 'Uniprot entry ID matching the Ensembl_proteinid\\nMultiple entries separated by ";".',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'Uniprot_entry'},
#   {'id': '597',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'aaalt',
#    'detail': 'alternative amino acid\\n"." if the variant is a splicing site SNP (2bp on each end of an intron)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'aaalt'},
#   {'id': '598',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'aapos',
#    'detail': 'amino acid position as to the protein.\\n"-1" if the variant is a splicing site SNP (2bp on each end of an intron). Multiple entries separated by ";", corresponding to Ensembl_proteinid\\nMultiple entries separated by ";", corresponding to Ensembl_proteinid',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'aapos'},
#   {'id': '599',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'aaref',
#    'detail': 'reference amino acid\\n"." if the variant is a splicing site SNP (2bp on each end of an intron)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'aaref'},
#   {'id': '600',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'cds_strand',
#    'detail': 'coding sequence (CDS) strand (+ or -)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'cds_strand'},
#   {'id': '601',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'codon_degeneracy',
#    'detail': 'degenerate type (0, 2 or 3)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'codon_degeneracy'},
#   {'id': '602',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'codonpos',
#    'detail': 'position on the codon (1, 2 or 3)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'codonpos'},
#   {'id': '603',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_coding_group',
#    'detail': 'fathmm-MKL coding group, the feature group used for the coding prediction.',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_MKL_coding_group'},
#   {'id': '604',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_coding_pred',
#    'detail': 'If a fathmm-MKL_coding_score is >0.5 the corresponding nsSNV\\nis predicted as "D(AMAGING)"; otherwise it is predicted as "N(EUTRAL)".',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_MKL_coding_pred'},
#   {'id': '605',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_coding_rankscore',
#    'detail': 'the rank of the fathmm-MKL_coding_score among all fathmm-MKL_coding_scores in genome',
#    'field_type': 'float',
#    'api_field': 'fathmm_MKL_coding_rankscore'},
#   {'id': '606',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_coding_score',
#    'detail': 'fathmm-MKL coding prediction probability, the larger the number the more likely damaging\\nthe threshold separating deleterious prediction and neutral prediction is 0.5.',
#    'field_type': 'float',
#    'api_field': 'fathmm_MKL_coding_score'},
#   {'id': '607',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_non-coding_group',
#    'detail': 'fathmm-MKL non-coding group, the feature group used for the non-coding prediction',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_MKL_non_coding_group'},
#   {'id': '608',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_non-coding_pred',
#    'detail': 'If a fathmm-MKL_non-coding_score is >0.5 the corresponding nsSNV\\nis predicted as "D(AMAGING)"; otherwise it is predicted as "N(EUTRAL)".',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_MKL_non_coding_pred'},
#   {'id': '609',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_non-coding_rankscore',
#    'detail': 'the rank of the fathmm-MKL_non-coding_score among all fathmm-MKL_non-coding_scores in genome',
#    'field_type': 'float',
#    'api_field': 'fathmm_MKL_non_coding_rankscore'},
#   {'id': '610',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-MKL_non-coding_score',
#    'detail': 'fathmm-MKL non-coding prediction probability, the larger the number the more likely damaging;\\nthe threshold separating deleterious prediction and neutral prediction is 0.5.',
#    'field_type': 'float',
#    'api_field': 'fathmm_MKL_non_coding_score'},
#   {'id': '611',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-XF_coding_or_noncoding',
#    'detail': 'whether the prediction is based on the model for coding region\\nor noncoding region',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_XF_coding_or_noncoding'},
#   {'id': '612',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-XF_pred',
#    'detail': 'If a fathmm-XF_score is >0.5 the corresponding nsSNV\\nis predicted as "D(AMAGING)"; otherwise it is predicted as "N(EUTRAL)".',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'fathmm_XF_pred'},
#   {'id': '613',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-XF_rankscore',
#    'detail': 'the rank of the fathmm-XF_score among all fathmm-XF_scores in genome',
#    'field_type': 'float',
#    'api_field': 'fathmm_XF_rankscore'},
#   {'id': '614',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'fathmm-XF_score',
#    'detail': 'fathmm-XF prediction probability, the larger the number the more likely damaging;\\nthe threshold separating deleterious prediction and neutral prediction is 0.5.',
#    'field_type': 'float',
#    'api_field': 'fathmm_XF_score'},
#   {'id': '615',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'funseq_noncoding_score',
#    'detail': 'funseq-like noncoding score range 0-6, each of the previous 5 columns\\ncontribute 1 if "YES", or 0 if "NO"; the column Motif_breaking contribute 1 if it is not a "."\\nnot a "."',
#    'field_type': 'long',
#    'api_field': 'funseq_noncoding_score'},
#   {'id': '616',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'genename',
#    'detail': 'gene name; if the nsSNV can be assigned to multiple genes, gene names are\\nseparated by ";"',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'genename'},
#   {'id': '617',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'network_hub',
#    'detail': 'whether the target gene is a network hub based on funseq-0.1',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'network_hub'},
#   {'id': '618',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'refcodon',
#    'detail': 'reference codon',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'refcodon'},
#   {'id': '619',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'sensitive',
#    'detail': 'whether defined as sensitive region based on funseq-0.1',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'sensitive'},
#   {'id': '620',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'sno_miRNA_name',
#    'detail': 'the name of snoRNA or miRNA if the site is located within (from miRBase/snoRNABase)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'sno_miRNA_name'},
#   {'id': '621',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'sno_miRNA_type',
#    'detail': 'the type of snoRNA or miRNA (from miRBase/snoRNABase)',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'sno_miRNA_type'},
#   {'id': '622',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'splicing_consensus_ada_score',
#    'detail': 'splicing-change prediction for splicing consensus SNPs\\nbased on adaboost. If the score >0.6, it predicts that the splicing will be changed, otherwise it predicts the splicing will not be changed.\\notherwise it predicts the splicing will not be changed.',
#    'field_type': 'float',
#    'api_field': 'splicing_consensus_ada_score'},
#   {'id': '623',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'splicing_consensus_rf_score',
#    'detail': 'splicing-change prediction for splicing consensus SNPs\\nbased on random forest. If the score >0.6, it predicts that the splicing will be changed, otherwise it predicts the splicing will not be changed\\notherwise it predicts the splicing will not be changed',
#    'field_type': 'float',
#    'api_field': 'splicing_consensus_rf_score'},
#   {'id': '624',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'target_gene',
#    'detail': 'target gene (for promoter, enhancer, etc.) based on funseq-0.1',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'target_gene'},
#   {'id': '625',
#    'parent_id': '495',
#    'leaf': True,
#    'name': 'ultra_sensitive',
#    'detail': 'whether defined as ultra-sensitive region based funseq-0.1',
#    'field_type': 'text',
#    'keyword_searchable': True,
#    'api_field': 'ultra_sensitive'}]}

# %% [markdown]
# ## Extracting SNP Data Through a GraphQL Query
#
# The script continues by constructing a GraphQL query designed to fetch specific information about Single Nucleotide Polymorphisms (SNPs) based on criteria such as chromosome number and position range. This query illustrates GraphQL's capability to precisely target and retrieve the needed data from the server, thus optimizing the data acquisition process. The response from this query provides detailed attributes of SNPs for subsequent processing or analysis.

# %%
query = """
query MyQuery {
  GetSNPsByChromosome(chr: "1", end: 1000000, start: 10) {
    alt {
      value
    }
    chr {
      value
    }
    pos {
      value
    }
    rs_dbSNP151 {
      value
    }
    ref {
      value
    }
    ANNOVAR_ensembl_Effect {
      value
    }
    ANNOVAR_refseq_Effect {
      value
    }
  }
}
"""

response = requests.post(f"{BASE_URL}{GRAPHQL_ENDPOINT}", json={'query': query})

data = json.loads(response.text)
snps_by_chromosome = data['data']['GetSNPsByChromosome']

# %% [markdown]
# ## Processing and Displaying the Data
#
# After receiving data from the GraphQL query, the script processes it for analysis. This involves flattening the nested structure of the data response to a more straightforward, table-like format.

# %%
flattened_data = [{k: v['value'] if v is not None else None for k, v in record.items()} for record in snps_by_chromosome]
flattened_data
snp_df = pd.DataFrame(flattened_data)
snp_df
# Out:
#    alt chr     pos   rs_dbSNP151 ref  \
# 0    A   1   54353   rs140052487   C
# 1    G   1   54763   rs548455890   T
# 2    C   1   55427   rs183189405   T
# 3    A   1   56586   rs541979596   G
# 4    C   1   56644   rs143342222   A
# 5    C   1   57033     rs2691311   T
# 6    C   1   62055   rs559425327   G
# 7    A   1   62162   rs140556834   G
# 8    G   1   64670   rs545257650   A
# 9    G   1   64904  rs1452689085   T
# 10   T   1   66861    rs28375825   C
# 11   T   1   67223    rs78676975   C
# 12   C   1   69534   rs190717287   T
# 13   C   1   69594   rs144967600   T
# 14   A   1   73093   rs535508237   G
# 15   G   1   77646  rs1216460540   C
# 16   T   1   77706   rs571772305   A
# 17   C   1   80454   rs144226842   G
# 18   C   1   81654   rs538957817   G
# 19   A   1   82365   rs530424422   G
# 20   G   1   83108          None   C
# 21   A   1   86192   rs548281277   G
# 22   T   1   89903  rs1461595625   C
# 23   G   1   94961   rs537800512   C
# 24   G   1  235886  rs1237499569   T
# 25   T   1  235920   rs113244325   C
# 26   C   1  267295   rs528900950   A
# 27   G   1  362895   rs190726048   A
# 28   G   1  526561    rs28780398   T
# 29   T   1  526692   rs143629215   C
# 30   T   1  526733    rs28760963   C
# 31   A   1  533188  rs1455107718   G
# 32   C   1  534297   rs190879900   T
# 33   G   1  536169   rs545933345   A
# 34   C   1  564766   rs368473365   T
# 35   C   1  564862     rs1988726   T
# 36   C   1  564920   rs577613042   T
# 37   A   1  565130   rs371431021   G
# 38   C   1  565136   rs530783041   T
# 39   C   1  565253   rs532570750   T
# 40   T   1  565469   rs554127336   C
# 41   A   1  565596     rs9782892   G
# 42   A   1  565999          None   C
# 43   A   1  566024     rs6421779   G
# 44   A   1  566700   rs537178084   G
# 45   C   1  566792     rs9283152   T
# 46   T   1  567006   rs565235853   G
# 47   C   1  567119     rs9283153   A
# 48   T   1  567137     rs9326623   C
# 49   C   1  568201     rs4098611   T
#
#                              ANNOVAR_ensembl_Effect ANNOVAR_refseq_Effect
# 0                         ncRNA_intronic|downstream            intergenic
# 1                         ncRNA_intronic|downstream            intergenic
# 2                                        downstream            intergenic
# 3                                        downstream            intergenic
# 4                                        downstream            intergenic
# 5                                        downstream            intergenic
# 6                                          upstream            intergenic
# 7                                          upstream            intergenic
# 8                               upstream|downstream              upstream
# 9                               upstream|downstream              upstream
# 10                              upstream|downstream              upstream
# 11                              upstream|downstream              upstream
# 12                                       synonymous            synonymous
# 13                                       synonymous            synonymous
# 14                                       downstream            downstream
# 15                                       intergenic            intergenic
# 16                                       intergenic            intergenic
# 17                                       intergenic            intergenic
# 18                                       intergenic            intergenic
# 19                                       intergenic            intergenic
# 20                                       intergenic            intergenic
# 21                                       downstream            intergenic
# 22                          ncRNA_exonic|downstream            intergenic
# 23                          ncRNA_intronic|upstream            intergenic
# 24               ncRNA_intronic|upstream|downstream            intergenic
# 25               ncRNA_intronic|upstream|downstream            intergenic
# 26                                         upstream            intergenic
# 27                          ncRNA_intronic|upstream              upstream
# 28               ncRNA_intronic|upstream|downstream            intergenic
# 29               ncRNA_intronic|upstream|downstream            intergenic
# 30               ncRNA_intronic|upstream|downstream            intergenic
# 31                              upstream|downstream            intergenic
# 32                              upstream|downstream            intergenic
# 33                              upstream|downstream            intergenic
# 34             ncRNA_exonic|ncRNA_intronic|upstream   upstream|downstream
# 35               ncRNA_intronic|upstream|downstream   upstream|downstream
# 36               ncRNA_intronic|upstream|downstream   upstream|downstream
# 37  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 38  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 39  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 40  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 41  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 42  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 43  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 44  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 45  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 46  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 47  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 48  ncRNA_exonic|ncRNA_intronic|upstream|downstream   upstream|downstream
# 49  ncRNA_exonic|ncRNA_intronic|upstream|downstream              upstream
